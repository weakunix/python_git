# %% [markdown]
# # **Problem 1 (100 points)**
#
# Let us consider the following sequence:
#
# $$
# F_n = F_{n-1} + F_{n-2} , \ \forall \ n \geq 2 .
# $$

# %% [markdown]
# Before starting this problem, make sure to run the following code first **without any change**:

# %%
# DO NOT CHANGE
import numpy as np
import matplotlib.pyplot as plt
""" END OF THIS PART """
# Out:
# ' END OF THIS PART '

# %% [markdown]
# $\color{red}{\text{WARNING !!!}}$
#
# * Beyond importing libraries/modules/classes/functions in the preceeding cell, you are **NOT allowed to import anything else for the following purposes**:
#
#     * **As a part of your final solution.** For instance, if a problem asks you to build a model without using sklearn but you use it, then you will not earn points.
#
#     * **Temporarily import something to assist you to get a solution.** For instance, if a problem asks you to manually compute eigenvalues but you temporarily use `np.linalg.eig` to get an answer and then delete your code, then you violate the rule.
#
#   **Rule of thumb:** Each part has its particular purpose to intentionally test you something. Do not attempt to find a shortcut to circumvent the rule.
#
# * All coding tasks shall run on CPUs, **not GPUs**.

# %% [markdown]
# ## **Part 1 (10 points, non-coding task)**
#
# Let $F_0 = 3$, $F_1 = 1$.
#
# **Manually write down $F_n$ for $n = 2, 3, 4 , 5$.**
#
# * Reasoning is not required.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# $F_2 = \boxed{4}$
#
# $F_3 = \boxed{5}$
#
# $F_4 = \boxed{9}$
#
# $F_5 = \boxed{14}$
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 2 (10 points, non-coding task)**
#
# The recursive equation that defines the sequence in this problem can be written in a matrix form:
#
# $$
# \begin{bmatrix}
# F_n \\
# F_{n-1}
# \end{bmatrix}
# = \mathbf{A}
# \begin{bmatrix}
# F_{n-1} \\
# F_{n-2}
# \end{bmatrix}, \ \forall \ n \geq 2 ,
# $$
#
# where $\mathbf{A} \in \Bbb R^{2 \times 2}$.
#
# **Compute $\mathbf{A}$.**
#
# * Reasoning is not required.
#
# * The value of each entry in $\mathbf{A}$ must be exact. For instance, the following values are exact: $\sqrt{3}$, $\frac{2}{\sqrt{7}}$, $\pi + \frac{3}{8}$, $e^2$, $\sin 40^\circ$, $\log 18$. However, their float approximations are not exact.

# %% [markdown]
# $\color{green}{\text{WRITE YOUR SOLUTION IN THIS TEXT CELL.}}$
#
# \begin{align}
#     \mathbf{A} = \boxed{
#         \begin{bmatrix}
#             1 & 1 \\
#             1 & 0
#         \end{bmatrix}
#     }
# \end{align}
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 3 (10 points, non-coding task)**
#
# **Explain why $\mathbf{A}$ is a symmetric matrix.**

# %% [markdown]
# $\color{green}{\text{WRITE YOUR SOLUTION IN THIS TEXT CELL.}}$
#
# Matrix $\mathbf{M}$ is symmetric if $\mathbf{M} = \mathbf{M}^\top$, which $\mathbf{A}$ clearly is.
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 4 (10 points, non-coding task)**
#
# **In this part, you are asked to prove a general result that holds for any real-valued symmetric matrix.**
#
# Let $\mathbf{U} \in \Bbb R^{N \times N}$ be a real-valued symmetric matrix.
#
# Consider the following eigenvalue equation
#
# $$
# \mathbf{U} \mathbf{v} = \lambda \mathbf{v} ,
# $$
#
# where $\lambda \in \Bbb R$ and $\mathbf{v} \in \Bbb R^{N \times 1}$.
#
# Let $\lambda_i$ and $\lambda_j$ be two distinct real eigenvalues and $\mathbf{v}_i, \mathbf{v}_j \in \Bbb R^{N \times 1}$ be two eigenvectors associated with them, respectively.
#
# Prove that
#
# $$
# \mathbf{v}_i^\top \mathbf{v}_j = 0 .
# $$
#
# That is, vectors $\mathbf{v}_i$ and $\mathbf{v}_j$ are orthogonal.

# %% [markdown]
# $\color{green}{\text{WRITE YOUR SOLUTION IN THIS TEXT CELL.}}$
#
# \begin{align}
#     \mathbf{U} \mathbf{v}_i &= \lambda_i \mathbf{v}_i \\
#     \mathbf{U} \mathbf{v}_j &= \lambda_j \mathbf{v}_j \\
#     \mathbf{v}_i^\top \mathbf{U}^\top &= \lambda_i \mathbf{v}_i^\top \\
#     \lambda_i \lambda_j \mathbf{v}_i^\top \mathbf{v}_j &= \mathbf{v}_i^\top \mathbf{U}^\top \mathbf{U} \mathbf{v}_j
# \end{align}
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 5 (10 points, non-coding task)**
#
# Let us go back to our matrix $\mathbf{A}$.
#
# In the following eigenvalue equation
#
# $$
# \mathbf{A} \mathbf{x} = \lambda \mathbf{x} ,
# $$
#
# **compute two eigenvalues $\lambda_0$ and $\lambda_1$ whose values are in a descending order.**
#
# * Reasoning is required.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# We want:
# \begin{align}
#     \det \left ( \mathbf{A} - \lambda \mathbf{I} \right ) &= 0 \\
#     \det \left (
#         \begin{bmatrix}
#             1 - \lambda & 1 \\
#             1 & -\lambda
#         \end{bmatrix}
#     \right ) &= 0 \\
#     \left ( 1 - \lambda \right ) \left ( -\lambda \right ) - 1 &= 0 \\
#     \lambda^2 - \lambda - 1 &= 0
# \end{align}
#
# Quadratic formula yields:
#
# $\lambda_0 = \boxed{\frac{1 + \sqrt{5}}{2}}$
#
# $\lambda_1 = \boxed{\frac{1 - \sqrt{5}}{2}}$
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# **In the remaining parts of this problem, for all non-coding tasks, when you need to use those eigenvalues,**
#
# $$
# \color{red}{\textbf{keep them as $\lambda_0$ and $\lambda_1$. No need to apply their formulae.}}
# $$

# %% [markdown]
# ## **Part 6 (10 points, non-coding task)**
#
# **Since matrix $\mathbf{A}$ is symmetric, let us do the spectral decomposition of it.**
#
# That is, you should write $\mathbf{A}$ in the following form:
#
# $$
# \mathbf{A} = \mathbf{Q} \mathbf{\Lambda} \mathbf{Q}^\top ,
# $$
#
# where
#
# * $\mathbf{Q} \in \Bbb R^{2 \times 2}$ is an orthonormal matrix.
#
# * $\mathbf{\Lambda} = \begin{bmatrix} \lambda_0 & 0 \\ 0 & \lambda_1 \end{bmatrix} \in \Bbb R^{2 \times 2}$ is a diagnomal matrix with $\lambda_0 > \lambda_1$
#
# **In this task, you need to compute $\mathbf{Q}$. Reasoning is required.**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# We are looking for:
# \begin{align}
#     \left ( \mathbf{A} - \lambda_i \mathbf{I} \right ) \mathbf{v}_i &= 0 \\
#     \begin{bmatrix}
#         1 - \lambda_i & 1 \\
#         1 & -\lambda_i
#     \end{bmatrix}
#     \begin{bmatrix}
#         a_i \\
#         b_i
#     \end{bmatrix}
#     &=
#     0
# \end{align}
#
# This gives:
# \begin{align}
#     a_i &= \lambda_i b_i
# \end{align}
#
# $\mathbf{Q}$ needs to be orthonormal so we need to normalize, making $a_i ^ 2 + b_i ^ 2 = 1$, so we must have:
# \begin{align}
#     \mathbf{Q} = \boxed{
#         \begin{bmatrix}
#             \frac{\lambda_0}{\sqrt{\lambda_0^2 + 1}} & \frac{\lambda_1}{\sqrt{\lambda_1^2 + 1}} \\
#             \frac{1}{\sqrt{\lambda_0^2 + 1}} & \frac{1}{\sqrt{\lambda_1^2 + 1}}
#         \end{bmatrix}
#     }
# \end{align}
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 7 (10 points, non-coding task)**
#
# **Use the spectral decomposition result to derive a closed form of $F_{n}$ for any $n \in \left\{ 0, 1, \cdots \right\}$.**
#
# * Reasoning is required.
#
# * Your answer shall be written in terms of $\lambda_0$, $\lambda_1$, and $F_0$ and $F_1$.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# $\mathbf{Q}$ is orthonormal so we use $\mathbf{Q}^{-1}$ and $\mathbf{Q}^\top$ interchangeably.
#
# We know that:
# \begin{align}
#     \begin{bmatrix}
#         F_{n+1} \\
#         F_n
#     \end{bmatrix}
#     &=
#     \mathbf{A}^n
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
#     &=
#     \left( \mathbf{Q} \mathbf{\Lambda} \mathbf{Q}^{-1} \right ) ^ n
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
#     &=
#     \mathbf{Q} \mathbf{\Lambda}^n \mathbf{Q}^\top
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
#     &=
#     \begin{bmatrix}
#         \frac{\lambda_0}{\sqrt{\lambda_0^2 + 1}} & \frac{\lambda_1}{\sqrt{\lambda_1^2 + 1}} \\
#         \frac{1}{\sqrt{\lambda_0^2 + 1}} & \frac{1}{\sqrt{\lambda_1^2 + 1}}
#     \end{bmatrix}
#     \begin{bmatrix}
#         \lambda_0 ^ n & 0 \\
#         0 & \lambda_1 ^ n
#     \end{bmatrix}
#     \begin{bmatrix}
#         \frac{\lambda_0}{\sqrt{\lambda_0^2 + 1}} & \frac{1}{\sqrt{\lambda_0^2 + 1}} \\
#         \frac{\lambda_1}{\sqrt{\lambda_1^2 + 1}} & \frac{1}{\sqrt{\lambda_1^2 + 1}}
#     \end{bmatrix}
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
#     &=
#     \begin{bmatrix}
#         \frac{\lambda_0 ^ {n+1}}{\sqrt{\lambda_0^2 + 1}} & \frac{\lambda_1 ^ {n+1}}{\sqrt{\lambda_1^2 + 1}} \\
#         \frac{\lambda_0 ^ n}{\sqrt{\lambda_0^2 + 1}} & \frac{\lambda_1 ^ n}{\sqrt{\lambda_1^2 + 1}}
#     \end{bmatrix}
#     \begin{bmatrix}
#         \frac{\lambda_0}{\sqrt{\lambda_0^2 + 1}} & \frac{1}{\sqrt{\lambda_0^2 + 1}} \\
#         \frac{\lambda_1}{\sqrt{\lambda_1^2 + 1}} & \frac{1}{\sqrt{\lambda_1^2 + 1}}
#     \end{bmatrix}
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
#     &=
#     \begin{bmatrix}
#         \frac{\lambda_0 ^ {n+2}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n+2}}{\lambda_1^2 + 1} & \frac{\lambda_0 ^ {n+1}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n+1}}{\lambda_1^2 + 1} \\
#         \frac{\lambda_0 ^ {n+1}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n+1}}{\lambda_1^2 + 1} & \frac{\lambda_0 ^ {n}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n}}{\lambda_1^2 + 1}
#     \end{bmatrix}
#     \begin{bmatrix}
#         F_1 \\
#         F_0
#     \end{bmatrix} \\
# \end{align}
#
# Solving for $F_n$:
# \begin{align}
#     F_n = \boxed{
#         \left ( \frac{\lambda_0 ^ {n+1}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n+1}}{\lambda_1^2 + 1} \right ) F_1 + \left ( \frac{\lambda_0 ^ {n}}{\lambda_0^2 + 1} + \frac{\lambda_1 ^ {n}}{\lambda_1^2 + 1} \right ) F_0
#     }
# \end{align}
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 8 (10 points, non-coding task)**
#
# **Compute**
#
# $$
# \lim_{n \rightarrow \infty} \ \frac{F_n}{F_{n-1}} .
# $$
#
# * Reasoning is required.
#
# * Your answer shall be written in terms of one or two eigenvalues.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
# Notice that $\left | \lambda_1 \right | < 1$ so $\lim_{n \rightarrow \infty} \lambda_1 ^ {n} = 0$.
#
# This means:
# \begin{align}
#     \lim_{n \rightarrow \infty} F_n &= \lambda_0 ^ {n-1} F_1 + \lambda_0 ^ {n-2} F_0
# \end{align}
#
# Finally:
# \begin{align}
#     \lim_{n \rightarrow \infty} \frac{F_n}{F_{n-1}} &=
#     \frac{\lambda_0 ^ {n-1} F_1 + \lambda_0 ^ {n-2} F_0}{\lambda_0 ^ {n-2} F_1 + \lambda_0 ^ {n-3} F_0} \\
#     &= \boxed{\lambda_0}
# \end{align}
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 9 (15 points, coding task)**
#
# **Define a class called `My_Fib`.**
#
# * Attributes: $ $
#
#     * `Q`: This attribute is matrix $\mathbf{Q}$ computed above. It is a numpy array with shape `(2,2)`.
#
#     * `lambdas`: This attribute is a numpy array with shape `(2,)` that includes two eigenvalues computed above.
#
# * Method `__init__`:
#
#     * All atttribute values shall be initialized when an object in this class is constructed.
#
# * Method `compute_fib`:
#
#     * This method computes the sequence values on designated indices.
#
#     * You must use the eigendecomposition result to write this method.
#
#     * **You are not allowed to use any loop.**
#
#     * Inputs:
#
#         * `f0`: The value of $F_0$
#
#         * `f1`: The value of $F_1$
#
#         * `indices`: a list/tuple/range object that includes indices with which the sequence values shall be computed.
#
#         For instance, if `indices` takes the value `[3, 5, 9]`, we need to compute $F_3$, $F_5$, $F_9$.
#
#         In our test cases, you are guaranteed that `len(indices)` is at least 1. You do not need to worry about the size of the test cases or whether the sequence values are too big (that is, on your side, you do not need to worry about those corner cases).
#
#     * Outputs:
#
#         * Return a numpy array `fib_values` with shape `(len(indices),)` and datatype `int32`.
#
#         * `fib_values[i]` takes the value of $F_{indices[i]}$.
#
#         For instance, if `indices` takes the value `[3, 5, 9]`, then `fib_values` has shape `(3,)`. The values of `fib_values[0]`, `fib_values[1]`, `fib_values[2]` are $F_3$, $F_5$, $F_9$, respectively.
#
#     * Inside this method:
#
#         * Print `fib_values`.
#
# * Method `plot_fib`:
#
#     * This method plots indices vs. sequence values on those indices.
#
#     * Inputs: The same as the method `compute_fib(f0, f1, indices)`.
#
#     * Outputs: None.
#
#     * In your plot,
#
#         * All data points with input indices are with marker `x`.
#
#         * The linestyle is `--`.
#
#         * The color is red.
#
#         * The x-lable is: $n$.
#
#         * The y-label is: $F_n$.
#
#         * The title is: Fibounacci sequence.

# %%
### WRITE YOUR SOLUTION HERE ###

class My_Fib:
    def __init__(self):
        a = (1 + 5 ** .5) / 2
        b = (1 - 5 ** .5) / 2
        self.lambdas = np.array([a, b])
        self.Q = np.array([
            [a / ((a ** 2 + 1) ** .5), b / ((b ** 2 + 1) ** .5)],
            [1 / ((a ** 2 + 1) ** .5), 1 / ((b ** 2 + 1) ** .5)]
        ])

    def compute_fib(self, f0, f1, indices):
        indices = np.array(indices)
        l0n = np.power(self.lambdas[0], indices)
        l1n = np.power(self.lambdas[1], indices)
        col1 = l0n * self.lambdas[0] / (self.lambdas[0] ** 2 + 1) + l1n * self.lambdas[1] / (self.lambdas[1] ** 2 + 1)
        col2 = l0n / (self.lambdas[0] ** 2 + 1) + l1n / (self.lambdas[1] ** 2 + 1)
        cur = np.hstack((col1.reshape(-1,1), col2.reshape(-1,1)))
        res = np.array(cur @ np.array([f1, f0]))
        res = np.round(res)
        res = np.array(res, dtype = np.int32)
        print(res)
        return res

    def plot_fib(self, f0, f1, indices):
        plt.plot(self.compute_fib(f0, f1, indices), 'r--')
        plt.xlabel('n')
        plt.ylabel('F_n')
        plt.title('Fibounacci sequence')
        plt.show()

""" END OF THIS PART """
# Out:
# ' END OF THIS PART '

# %% [markdown]
# ## **Part 10 (5 points, coding task)**
#
# **Do the following tasks in this part.**
#
# * Define an object of the class `My_Fib` called `my_fib`.
#
# * Set `f0 = 0`, `f1 = 1`, `indices = range(10)`.
#
# * Call method `my_fib.plot_fib(f0, f1, indices)`.

# %%
### WRITE YOUR SOLUTION HERE ###

my_fib = My_Fib()
my_fib.plot_fib(3, 1, range(10))

""" END OF THIS PART """
# Out:
# [ 3  1  4  5  9 14 23 37 60 97]
# ' END OF THIS PART '

# %% [markdown]
# **END OF THIS PROBLEM**
